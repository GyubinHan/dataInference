# %%
# !pip install elasticsearch
# Out:
# Collecting elasticsearch
#   Using cached elasticsearch-8.8.0-py3-none-any.whl (393 kB)
# Collecting elastic-transport<9,>=8 (from elasticsearch)
#   Using cached elastic_transport-8.4.0-py3-none-any.whl (59 kB)
# Requirement already satisfied: urllib3<2,>=1.26.2 in /opt/homebrew/lib/python3.10/site-packages (from elastic-transport<9,>=8->elasticsearch) (1.26.12)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.10/site-packages (from elastic-transport<9,>=8->elasticsearch) (2022.6.15)
# Installing collected packages: elastic-transport, elasticsearch
# Successfully installed elastic-transport-8.4.0 elasticsearch-8.8.0

# %%
from elasticsearch import Elasticsearch,exceptions
import time
import pandas as pd 
_KEEP_ALIVE_LIMIT='20s'



# os environment

es = Elasticsearch('http://elastic:ndxpro123!@172.16.28.220:59200')
index = "metricbeat-7.17.0*"

query = {
            "query":{
                "bool":{
                    "must":[
                        {
                        "match":{
                            "metricset.name":"cpu"
                        }
                        },
                        {
                        "match":{
                            "container.name":"data-broker-2"
                            # "container.name": CONTAINER_NAME
                            
                            # "localEndpoint.serviceName":SERVICE_NAME
                            
                        }
                        }
                    ]
                }
            # },
            }
            # "_source":[
            #     "duration",
            #     "localEndpoint.serviceName",
            #     "timestamp_millis",
            #     "name"
            # ]
            
}

# %%
from elasticsearch import Elasticsearch
import elasticsearch.helpers
import pandas as pd
results = elasticsearch.helpers.scan(es, body= query, index=index)
df = pd.DataFrame.from_dict([document['_source'] for document in results])

print(df.head())
# Out:
# /var/folders/g5/vb53_0n544nbg5lj9697b1080000gn/T/ipykernel_36064/582791464.py:5: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   df = pd.DataFrame.from_dict([document['_source'] for document in results])
#                  @timestamp  \
# 0  2023-06-21T01:02:14.642Z
# 1  2023-06-21T01:02:15.646Z
# 2  2023-06-20T23:18:40.581Z
# 3  2023-06-21T01:02:16.650Z
# 4  2023-06-20T23:18:41.584Z
#
#                                            container  \
# 0  {'id': 'ca97014f52c4790363a288f5bdab79246eebc2...
# 1  {'id': 'ca97014f52c4790363a288f5bdab79246eebc2...
# 2  {'image': {'name': '172.16.28.217:12000/ndxpro...
# 3  {'image': {'name': '172.16.28.217:12000/ndxpro...
# 4  {'runtime': 'docker', 'id': 'ca97014f52c479036...
#
#                                               docker                    ecs  \
# 0  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
# 1  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
# 2  {'cpu': {'kernel': {'ticks': 0, 'pct': 0, 'nor...  {'version': '1.12.0'}
# 3  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
# 4  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
#
#                      host                                              agent  \
# 0  {'name': 'metricbeat'}  {'id': '7fa4d73e-f742-4121-b8a5-ae5bc4d48d00',...
# 1  {'name': 'metricbeat'}  {'ephemeral_id': 'c3392683-e661-4dfe-9553-2fdd...
# 2  {'name': 'metricbeat'}  {'name': 'metricbeat', 'type': 'metricbeat', '...
# 3  {'name': 'metricbeat'}  {'version': '7.17.0', 'hostname': '47405c3ec32...
# 4  {'name': 'metricbeat'}  {'name': 'metricbeat', 'type': 'metricbeat', '...
#
#                                                event  \
# 0  {'duration': 1003346079, 'dataset': 'docker.cp...
# 1  {'duration': 1003044894, 'dataset': 'docker.cp...
# 2  {'module': 'docker', 'duration': 1003525752, '...
# 3  {'module': 'docker', 'duration': 1002520544, '...
# 4  {'module': 'docker', 'duration': 1003660634, '...
#
#                          metricset  \
# 0  {'name': 'cpu', 'period': 1000}
# 1  {'name': 'cpu', 'period': 1000}
# 2  {'period': 1000, 'name': 'cpu'}
# 3  {'name': 'cpu', 'period': 1000}
# 4  {'period': 1000, 'name': 'cpu'}
#
#                                              service
# 0  {'address': 'unix:///var/run/docker.sock', 'ty...
# 1  {'address': 'unix:///var/run/docker.sock', 'ty...
# 2  {'type': 'docker', 'address': 'unix:///var/run...
# 3  {'address': 'unix:///var/run/docker.sock', 'ty...
# 4  {'address': 'unix:///var/run/docker.sock', 'ty...

# %%
df.head()
# Out:
#                  @timestamp  \
# 0  2023-06-21T01:02:14.642Z
# 1  2023-06-21T01:02:15.646Z
# 2  2023-06-20T23:18:40.581Z
# 3  2023-06-21T01:02:16.650Z
# 4  2023-06-20T23:18:41.584Z
#
#                                            container  \
# 0  {'id': 'ca97014f52c4790363a288f5bdab79246eebc2...
# 1  {'id': 'ca97014f52c4790363a288f5bdab79246eebc2...
# 2  {'image': {'name': '172.16.28.217:12000/ndxpro...
# 3  {'image': {'name': '172.16.28.217:12000/ndxpro...
# 4  {'runtime': 'docker', 'id': 'ca97014f52c479036...
#
#                                               docker                    ecs  \
# 0  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
# 1  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
# 2  {'cpu': {'kernel': {'ticks': 0, 'pct': 0, 'nor...  {'version': '1.12.0'}
# 3  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
# 4  {'container': {'labels': {'com_docker_compose_...  {'version': '1.12.0'}
#
#                      host                                              agent  \
# 0  {'name': 'metricbeat'}  {'id': '7fa4d73e-f742-4121-b8a5-ae5bc4d48d00',...
# 1  {'name': 'metricbeat'}  {'ephemeral_id': 'c3392683-e661-4dfe-9553-2fdd...
# 2  {'name': 'metricbeat'}  {'name': 'metricbeat', 'type': 'metricbeat', '...
# 3  {'name': 'metricbeat'}  {'version': '7.17.0', 'hostname': '47405c3ec32...
# 4  {'name': 'metricbeat'}  {'name': 'metricbeat', 'type': 'metricbeat', '...
#
#                                                event  \
# 0  {'duration': 1003346079, 'dataset': 'docker.cp...
# 1  {'duration': 1003044894, 'dataset': 'docker.cp...
# 2  {'module': 'docker', 'duration': 1003525752, '...
# 3  {'module': 'docker', 'duration': 1002520544, '...
# 4  {'module': 'docker', 'duration': 1003660634, '...
#
#                          metricset  \
# 0  {'name': 'cpu', 'period': 1000}
# 1  {'name': 'cpu', 'period': 1000}
# 2  {'period': 1000, 'name': 'cpu'}
# 3  {'name': 'cpu', 'period': 1000}
# 4  {'period': 1000, 'name': 'cpu'}
#
#                                              service
# 0  {'address': 'unix:///var/run/docker.sock', 'ty...
# 1  {'address': 'unix:///var/run/docker.sock', 'ty...
# 2  {'type': 'docker', 'address': 'unix:///var/run...
# 3  {'address': 'unix:///var/run/docker.sock', 'ty...
# 4  {'address': 'unix:///var/run/docker.sock', 'ty...

# %%
df[:1]
# Out:
#                  @timestamp  \
# 0  2023-06-21T01:04:41.241Z
#
#                                                event  \
# 0  {'dataset': 'docker.cpu', 'module': 'docker', ...
#
#                          metricset                    ecs  \
# 0  {'name': 'cpu', 'period': 1000}  {'version': '1.12.0'}
#
#                      host                                              agent  \
# 0  {'name': 'metricbeat'}  {'hostname': '47405c3ec32a', 'ephemeral_id': '...
#
#                                              service  \
# 0  {'address': 'unix:///var/run/docker.sock', 'ty...
#
#                                            container  \
# 0  {'id': 'ca97014f52c4790363a288f5bdab79246eebc2...
#
#                                               docker
# 0  {'cpu': {'user': {'norm': {'pct': 0}, 'ticks':...

# %%
df[:1]['metricset']['cpi']
# Out:
# {"@timestamp":{"0":"2023-06-21T01:04:41.241Z"},"event":{"0":{"dataset":"docker.cpu","module":"docker","duration":1002982662}},"metricset":{"0":{"name":"cpu","period":1000}},"ecs":{"0":{"version":"1.12.0"}},"host":{"0":{"name":"metricbeat"}},"agent":{"0":{"hostname":"47405c3ec32a","ephemeral_id":"c3392683-e661-4dfe-9553-2fdd5c142e48","id":"7fa4d73e-f742-4121-b8a5-ae5bc4d48d00","name":"metricbeat","type":"metricbeat","version":"7.17.0"}},"service":{"0":{"address":"unix:\/\/\/var\/run\/docker.sock","type":"docker"}},"container":{"0":{"id":"ca97014f52c4790363a288f5bdab79246eebc262a6ab6bb65a81d38614651010","name":"data-broker-2","image":{"name":"172.16.28.217:12000\/ndxpro-core-databroker:v1.4.5"},"runtime":"docker"}},"docker":{"0":{"cpu":{"user":{"norm":{"pct":0},"ticks":0,"pct":0},"system":{"ticks":0,"pct":0,"norm":{"pct":0}},"core":{},"total":{"norm":{"pct":0},"pct":0},"kernel":{"ticks":0,"pct":0,"norm":{"pct":0}}},"container":{"labels":{"com_docker_compose_service":"data-broker-2","com_docker_compose_container-number":"1","com_docker_compose_oneoff":"False","com_docker_compose_config-hash":"c8d15e7039f5bf9f41a470c71d30236e6b7efe7a430f455e834e7007713bad4c","com_docker_compose_image":"sha256:cfc2a5673b25c62b81539f2fcbdfbd64b763fcbb4ba3e1a7a21eb8866ad89f91","com_docker_compose_project_working_dir":"\/root\/docker-compose","com_docker_compose_version":"2.3.4","com_docker_compose_depends_on":"gateway:service_started,mongodb:service_started,data-manager:service_started,eureka:service_started","com_docker_compose_project_config_files":"\/root\/docker-compose\/docker-compose.yml","com_docker_compose_project":"docker-compose"}}}}}
