# %%
import os, random
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

from tqdm.notebook import trange
# from TaPR_pkg import etapr
from pathlib import Path
import time

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import plotly.graph_objects as go



# Set seeds to make the experiment more reproducible.
def seed_everything(seed=28):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

seed = 28
seed_everything()

## 데이터 로드
metric1 = pd.read_csv("metricbeat-230911-ai-broker-1.csv")
metric2 = pd.read_csv("metricbeat-230911-ai-broker-2.csv")
metric3 = pd.read_csv("metricbeat-230911-ai-broker-3.csv")
metric4 = pd.read_csv("metricbeat-230911-ai-broker-4.csv")
metric5 = pd.read_csv("metricbeat-230911-ai-broker-5.csv")




zipkin1 = pd.read_csv("zipkin-230911-all-broker.csv")



# print(zipkin.shape)

# print(metric1.head())
# print(zipkin.head())

metric_lst = [metric1,metric2,metric3,metric4,metric5]
# metric_merge = pd.merge(metric1,metric2, on='container_name')
metric_merge = pd.concat([metric1,metric2,metric3,metric4,metric5])
zipkin_merge = pd.concat([zipkin1])

metric_merge.drop(['Unnamed: 0'], axis = 1, inplace = True)
metric_merge.drop(['new_index'], axis = 1, inplace = True)
zipkin_merge.drop(['Unnamed: 0'], axis = 1, inplace = True)
zipkin_merge.drop(['new_index'], axis = 1, inplace = True)
zipkin_merge.drop_duplicates(['traceId'],keep='first')

##### data merge
merged = pd.merge(metric_merge, zipkin_merge,left_on='timestamp_5seconds', right_on='timestamp_5seconds',how='right')
merged = merged.dropna()


merged_grouped = merged.groupby(merged['traceId'])
merged_grouped = merged_grouped['cpu_usage'].mean()
merged_grouped = merged_grouped.reset_index()
merged_grouped['cpu_mean'] = merged_grouped['cpu_usage']
merged_final = pd.merge(merged,merged_grouped,on='traceId')
merged_final.drop(['cpu_usage_y'],inplace=True, axis=1)
print(merged_final)
merged_final['metricset_timestamp'] = pd.to_datetime(merged_final['metricset_timestamp'])


test =  merged_final.loc[merged_final['metricset_timestamp'] >= '2023-09-09']
scaler = StandardScaler()
scaler = scaler.fit(test[['cpu_mean']])

# train['cpu_mean'] = scaler.transform(train[['cpu_mean']])
test['cpu_mean'] = scaler.transform(test[['cpu_mean']])
new_model = tf.keras.models.load_model('/Users/e8l-20210032/Documents/GyubinHanAI/dataInference/lstmautoencodermodel/230911model_checkpoint_30.h5')
print(new_model)



TIME_STEPS=100

def create_sequences(X, y, time_steps=TIME_STEPS):
    Xs, ys = [], []
    for i in range(len(X)-time_steps):
        Xs.append(X.iloc[i:(i+time_steps)].values)
        ys.append(y.iloc[i+time_steps])
    
    return np.array(Xs), np.array(ys)

X_test, y_test = create_sequences(test[['cpu_mean']], test['cpu_mean'])

# plt.plot(history.history['loss'], label='Training loss')
# plt.plot(history.history['val_loss'], label='Validation loss')
# plt.legend()

evaluation = new_model.evaluate(X_test, y_test)
# print(new_model.evaluate(X_test, y_test))
# Out:
#           container_name  cpu_usage_x  metricset_timestamp  \
# 0       data-broker-ai-1     0.003090  2023-09-09T01:13:35
# 1       data-broker-ai-2     0.003257  2023-09-09T01:13:35
# 2       data-broker-ai-3     0.002994  2023-09-09T01:13:35
# 3       data-broker-ai-4     0.003217  2023-09-09T01:13:35
# 4       data-broker-ai-5     0.003503  2023-09-09T01:13:35
# ...                  ...          ...                  ...
# 552730  data-broker-ai-1     0.002756  2023-09-09T01:14:20
# 552731  data-broker-ai-2     0.003040  2023-09-09T01:14:20
# 552732  data-broker-ai-3     0.003352  2023-09-09T01:14:20
# 552733  data-broker-ai-4     0.003003  2023-09-09T01:14:20
# 552734  data-broker-ai-5     0.002593  2023-09-09T01:14:20
#
#          timestamp_5seconds           service_name  \
# 0       2023-09-09 01:13:35  databroker-ai-service
# 1       2023-09-09 01:13:35  databroker-ai-service
# 2       2023-09-09 01:13:35  databroker-ai-service
# 3       2023-09-09 01:13:35  databroker-ai-service
# 4       2023-09-09 01:13:35  databroker-ai-service
# ...                     ...                    ...
# 552730  2023-09-09 01:14:20  databroker-ai-service
# 552731  2023-09-09 01:14:20  databroker-ai-service
# 552732  2023-09-09 01:14:20  databroker-ai-service
# 552733  2023-09-09 01:14:20  databroker-ai-service
# 552734  2023-09-09 01:14:20  databroker-ai-service
#
#                                              api_name     zipkin_timestamp  \
# 0       get /ndxpro/v1/aibroker/entities/iot/temporal  2023-09-09T01:13:36
# 1       get /ndxpro/v1/aibroker/entities/iot/temporal  2023-09-09T01:13:36
# 2       get /ndxpro/v1/aibroker/entities/iot/temporal  2023-09-09T01:13:36
# 3       get /ndxpro/v1/aibroker/entities/iot/temporal  2023-09-09T01:13:36
# 4       get /ndxpro/v1/aibroker/entities/iot/temporal  2023-09-09T01:13:36
# ...                                               ...                  ...
# 552730   get /ndxpro/v1/aibroker/entities/iot/history  2023-09-09T01:14:21
# 552731   get /ndxpro/v1/aibroker/entities/iot/history  2023-09-09T01:14:21
# 552732   get /ndxpro/v1/aibroker/entities/iot/history  2023-09-09T01:14:21
# 552733   get /ndxpro/v1/aibroker/entities/iot/history  2023-09-09T01:14:21
# 552734   get /ndxpro/v1/aibroker/entities/iot/history  2023-09-09T01:14:21
#
#         duration           traceId  cpu_mean
# 0           6.90  7a5241ed4dd889f2  0.003212
# 1           6.90  7a5241ed4dd889f2  0.003212
# 2           6.90  7a5241ed4dd889f2  0.003212
# 3           6.90  7a5241ed4dd889f2  0.003212
# 4           6.90  7a5241ed4dd889f2  0.003212
# ...          ...               ...       ...
# 552730      2.93  6907577cc372b7d3  0.002949
# 552731      2.93  6907577cc372b7d3  0.002949
# 552732      2.93  6907577cc372b7d3  0.002949
# 552733      2.93  6907577cc372b7d3  0.002949
# 552734      2.93  6907577cc372b7d3  0.002949
#
# [552735 rows x 10 columns]
# <keras.src.engine.sequential.Sequential object at 0x29c1c8580>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 101
#      97         ys.append(y.iloc[i+time_steps])
#      99     return np.array(Xs), np.array(ys)
# --> 101 X_test, y_test = create_sequences(test[['cpu_mean']], test['cpu_mean'])
#     103 # plt.plot(history.history['loss'], label='Training loss')
#     104 # plt.plot(history.history['val_loss'], label='Validation loss')
#     105 # plt.legend()
#     107 evaluation = new_model.evaluate(X_test, y_test)
#
# Cell In [4], line 96, in create_sequences(X, y, time_steps)
#      94 Xs, ys = [], []
#      95 for i in range(len(X)-time_steps):
# ---> 96     Xs.append(X.iloc[i:(i+time_steps)].values)
#      97     ys.append(y.iloc[i+time_steps])
#      99 return np.array(Xs), np.array(ys)
#
# KeyboardInterrupt:

# %%
X_test_pred = new_model.predict(X_test, verbose =0)
print(X_test_pred)
print(len(X_test_pred))
test_mae_loss = np.mean(np.abs(X_test_pred - X_test), axis=1)
test_threshold = np.max(test_mae_loss)
print(f'Reconstruction error test threshold: {test_threshold}')

# mse = np.mean(np.power(flatten(X_test) - flatten(X_test_pred), 2), axis=1)

# error_df = pd.DataFrame({'Reconstruction_error':mse, 
#                          'True_class':list(y_valid)})
# precision_rt, recall_rt, threshold_rt = metrics.precision_recall_curve(error_df['True_class'], error_df['Reconstruction_error'])


test_score_df = pd.DataFrame(test[100:])
test_score_df['loss'] = test_mae_loss
test_score_df['threshold'] = test_threshold
test_score_df['anomaly'] = test_score_df['loss'] > test_score_df['threshold']
test_score_df['cpu_mean'] = test[TIME_STEPS:]['cpu_mean']
print(test_score_df)
print(test_score_df['threshold'])



fig = go.Figure()
fig.add_trace(go.Scatter(x=test_score_df['metricset_timestamp'], y=test_score_df['loss'], name='Test loss'))
fig.add_trace(go.Scatter(x=test_score_df['metricset_timestamp'], y=test_score_df['threshold'], name='Threshold'))
fig.update_layout(showlegend=True, title='Test loss vs. Threshold')
fig.show()
# Out:
# [[[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  ...
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]]
# 552635
# Reconstruction error test threshold: 1.86806523750088
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [18], line 16
#       8 # mse = np.mean(np.power(flatten(X_test) - flatten(X_test_pred), 2), axis=1)
#       9
#      10 # error_df = pd.DataFrame({'Reconstruction_error':mse,
#      11 #                          'True_class':list(y_valid)})
#      12 # precision_rt, recall_rt, threshold_rt = metrics.precision_recall_curve(error_df['True_class'], error_df['Reconstruction_error'])
#      15 test_score_df = pd.DataFrame(test[1000:])
# ---> 16 test_score_df['loss'] = test_mae_loss
#      17 test_score_df['threshold'] = test_threshold
#      18 test_score_df['anomaly'] = test_score_df['loss'] > test_score_df['threshold']
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:4905, in DataFrame._sanitize_column(self, value)
#    4902     return _reindex_for_setitem(Series(value), self.index)
#    4904 if is_list_like(value):
# -> 4905     com.require_length_match(value, self.index)
#    4906 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (552635) does not match length of index (551735)

# %%
print(test_score_df)
# print(threshold)
anomalies = test_score_df.loc[test_score_df['anomaly'] == True]
anomalies.shape
print(anomalies)
fig = go.Figure()
fig.add_trace(go.Scatter(x=test_score_df['metricset_timestamp'], y=test_score_df['cpu_mean'], name='cpu_mean'))
fig.add_trace(go.Scatter(x=anomalies['metricset_timestamp'], y=anomalies['cpu_mean'], mode='markers', name='Anomaly'))
fig.update_layout(showlegend=True, title='Detected anomalies')
fig.show()

# %%
from sklearn.metrics import confusion_matrix
print(X_test_pred)
print(y_test)

y_prediction = np.argmax(X_test_pred, axis = 1)
y_test=np.argmax(y_test, axis = 0)
print(y_test)
print(y_prediction)
from sklearn.metrics import accuracy_score, precision_score
accuracy_test_rnn= accuracy_score(y_test, X_test_pred)
accuracy_test_rnn
result = confusion_matrix(y_test, y_prediction , normalize='pred')
print(result)
# Out:
# [[[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  ...
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]
#
#  [[0.00230181]
#   [0.00230181]
#   [0.00230181]
#   ...
#   [0.00230181]
#   [0.00230181]
#   [0.00230181]]]
# 0
# 0
# [[0]
#  [0]
#  [0]
#  ...
#  [0]
#  [0]
#  [0]]
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In [27], line 10
#       8 print(y_prediction)
#       9 from sklearn.metrics import accuracy_score, precision_score
# ---> 10 accuracy_test_rnn= accuracy_score(y_test, X_test_pred)
#      11 accuracy_test_rnn
#      12 result = confusion_matrix(y_test, y_prediction , normalize='pred')
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'y_true' parameter of accuracy_score must be an array-like or a sparse matrix. Got 0 instead.

# %%
from sklearn.metrics import accuracy_score, precision_score
accuracy_test_rnn= accuracy_score(y_test, X_test_pred)
accuracy_test_rnn
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In [21], line 2
#       1 from sklearn.metrics import accuracy_score, precision_score
# ----> 2 accuracy_test_rnn= accuracy_score(y_test, X_test_pred)
#       3 accuracy_test_rnn
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'y_true' parameter of accuracy_score must be an array-like or a sparse matrix. Got 0 instead.
